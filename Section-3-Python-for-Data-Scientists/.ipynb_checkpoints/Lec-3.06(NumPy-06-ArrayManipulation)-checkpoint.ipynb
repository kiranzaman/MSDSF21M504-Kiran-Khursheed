# %% [markdown]
# ---
#  <img align="left" width="75" height="75"  src="https://upload.wikimedia.org/wikipedia/en/c/c8/University_of_the_Punjab_logo.png">
#
# <h1 align="center">Department of Data Science</h1>
# <h1 align="center">Course: Tools and Techniques for Data Science</h1>
#
# ---
# <h3><div align="right">Instructor: Muhammad Arif Butt, Ph.D.</div></h3>

# %% [markdown]
# <h1 align="center">Lecture 3.6 (NumPy-06)</h1>

# %% [markdown]
# # _Manipulating Array Elements.ipynb_

# %% [markdown]
# <img align="right" width="400" height="400"  src="images/numpy123D.png" >
#
# # Learning agenda of this notebook
#
# 1. Updating existing values of NumPy array elements
# 2. Append new elements to a NumPy array using np.append()
# 3. Insert new elements in a NumPy array using np.insert()
# 4. Delete elements of a NumPy array using np.delete()
# 5. Alias vs Shallow Copy vs Deep Copy

# %%
# To install this library in Jupyter notebook
#import sys
#!{sys.executable} -m pip install numpy

# %%
import numpy as np
np.__version__ , np.__path__
# Out:
# ('1.20.3', ['C:\\Users\\Kiran\\anaconda3\\lib\\site-packages\\numpy'])

# %% [markdown]
# ## 1. Updating Existing Values of Numpy Array Elements

# %% [markdown]
# ### a. 1-D Arrays

# %%
arr = np.random.randint(low = 1, high = 100, size = 10)
print("Original Array \n", arr)
arr[2] = 333
arr[-1] = 777
print("Updated Array \n", arr)
# Out:
# Original Array
#  [84 87 73 94 12 70 67 57 50 89]
# Updated Array
#  [ 84  87 333  94  12  70  67  57  50 777]

# %% [markdown]
# ### b. 2-D Arrays

# %%
# Creating 2-D array of size 4x4 of int type b/w interval 1 to 9
arr = np.random.randint(low = 1, high = 10, size = (4, 4))
print("Original Array \n", arr)
arr[0][1] = 77
arr[1][2] = 66
arr[2][-1] = 22
print("Updated Array \n", arr)
# Out:
# Original Array
#  [[8 8 7 4]
#  [3 7 3 8]
#  [4 6 1 2]
#  [1 7 1 6]]
# Updated Array
#  [[ 8 77  7  4]
#  [ 3  7 66  8]
#  [ 4  6  1 22]
#  [ 1  7  1  6]]

# %% [markdown]
# ## 2. Append New Elements to Numpy Arrays
# - The `np.append()` method allows us to insert new values at the end of a NumPy array.
# - The method always returns a copy of the existing numpy array with the values appended to the given axis.
# ```
# np.append(arr, values, axis=None)
# ```
# - Where,
#     - `arr` is the array in which we want to append
#     - `values` must be of the correct shape (the same shape as `arr` excluding `axis`)
#     - If `axis` is not specified, both `arr` and `values` are flattened before use.
#     - If `axis` is specified, then `values` must be of the correct shape (the same shape as `arr` excluding `axis`)
# - The original array remains as such, as it does not occur in-place.

# %% [markdown]
# ### a. Appending Elements in 1-D Arrays

# %%
arr1 = np.random.randint(low = 1, high = 100, size = 10)
print("arr1 = ", arr1)
# Out:
# arr1 =  [41 31 43 60 16  6 80 80 37 15]

# %%
# You can add a scalar value or a list of values at the end of a 1-D array
arr2 = np.append(arr1, 12)
print("After append:")
print("arr1 = ", arr1)
print("arr2 = ", arr2)
# Out:
# After append:
# arr1 =  [41 31 43 60 16  6 80 80 37 15]
# arr2 =  [41 31 43 60 16  6 80 80 37 15 12]

# %%
# You can add a scalar value or a list of values at the end of a 1-D array
arr2 = np.append(arr1, [101, 202,303])
print("After append:")
print("arr1 = ", arr1)
print("arr2 = ", arr2)
# Out:
# After append:
# arr1 =  [41 31 43 60 16  6 80 80 37 15]
# arr2 =  [ 41  31  43  60  16   6  80  80  37  15 101 202 303]

# %%
arr1[0] = 10

# %%
arr1
# Out:
# array([10, 31, 43, 60, 16,  6, 80, 80, 37, 15])

# %%
arr2
# Out:
# array([ 41,  31,  43,  60,  16,   6,  80,  80,  37,  15, 101, 202, 303])

# %%
len(arr2)
# Out:
# 13

# %%
arr2[1] = 0

# %%
print(arr2)
print(arr1)
# Out:
# [ 41   0  43  60  16   6  80  80  37  15 101 202 303]
# [10 31 43 60 16  6 80 80 37 15]

# %%
print(id(arr1))
print(id(arr2))
# Out:
# 2187813043056
# 2187814228400

# %% [markdown]
# ### b. Appending Elements in 2-D Arrays

# %% [markdown]
# **Example:** In case of 2-D Arrays if `axis` is not mentioned both `arr` and `values` are flattened before use

# %%
arr1 = np.random.randint(low = 1, high = 10, size = (3,3))
print("arr1 = \n", arr1)
# Out:
# arr1 =
#  [[1 6 7]
#  [1 1 8]
#  [9 1 5]]

# %%
# If the axis is not mentioned, values can be of any shape and both `arr` and `values` are flattened before use.
arr2 = np.append(arr1, 'hello')
print("After append:")
print("arr1 = \n", arr1)
print("arr2 = ", arr2)
# Out:
# After append:
# arr1 =
#  [[1 6 7]
#  [1 1 8]
#  [9 1 5]]
# arr2 =  ['1' '6' '7' '1' '1' '8' '9' '1' '5' 'hello']

# %%
# If the axis is not mentioned, values can be of any shape and both `arr` and `values` are flattened before use.
arr2 = np.append(arr1, 123)
print("After append:")
print("arr1 = \n", arr1)
print("arr2 = ", arr2)
# Out:
# After append:
# arr1 =
#  [[1 6 7]
#  [1 1 8]
#  [9 1 5]]
# arr2 =  [  1   6   7   1   1   8   9   1   5 123]

# %%
# If the axis is not mentioned, values can be of any shape and both `arr` and `values` are flattened before use.
arr2 = np.append(arr1, [101, 202,303, 404, 505])
print("After append:")
print("arr1 = \n", arr1)
print("arr2 = ", arr2)
# Out:
# After append:
# arr1 =
#  [[1 6 7]
#  [1 1 8]
#  [9 1 5]]
# arr2 =  [  1   6   7   1   1   8   9   1   5 101 202 303 404 505]

# %% [markdown]
# **Example:** Appending a Row to a 2-D array (`axis=0`)

# %%
arr1 = np.random.randint(low = 1, high = 10, size = (4,3))
print("arr1 = \n", arr1)
print("shape: ", arr1.shape)
# Out:
# arr1 =
#  [[2 9 1]
#  [5 8 5]
#  [9 3 4]
#  [4 3 4]]
# shape:  (4, 3)

# %%
# For appending at axis 0, the values argument must the same shape as `arr` excluding `axis`
# so the values should be a row vector, and in this case of shape (1,3), having 1 row and 3 columns
print("arr1: \n", arr1)
arr2 = np.append(arr1, [[101, 202,303]], axis=0)
print("After append:")
print("arr1 = \n", arr1)
print("arr2 = \n", arr2)
# Out:
# arr1:
#  [[9 3 1]
#  [7 7 8]
#  [1 5 5]
#  [4 1 8]]
# After append:
# arr1 =
#  [[9 3 1]
#  [7 7 8]
#  [1 5 5]
#  [4 1 8]]
# arr2 =
#  [[  9   3   1]
#  [  7   7   8]
#  [  1   5   5]
#  [  4   1   8]
#  [101 202 303]]

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# **Example:** Appending a Column to a 2-D array (`axis=1`)

# %%
arr1 = np.random.randint(low = 1, high = 10, size = (4,3))
print("arr1 = \n", arr1)
print("shape: ", arr1.shape)
# Out:
# arr1 =
#  [[9 3 1]
#  [7 7 8]
#  [1 5 5]
#  [4 1 8]]
# shape:  (4, 3)

# %%
# For appending at axis 1, the values argument must the same shape as `arr` excluding `axis`
# so the values should be a column vector of shape (4,1), having 4 rows and 1 column
arr2 = np.append(arr1, [[101], [202], [303], [404]], axis=1)
print("After append:")
print("arr1 = \n", arr1)
print("arr2 = \n", arr2)
# Out:
# [[  9   3   1 101]
#  [  7   7   8 202]
#  [  1   5   5 303]
#  [  4   1   8 404]]
# After append:
# arr1 =
#  [[9 3 1]
#  [7 7 8]
#  [1 5 5]
#  [4 1 8]]
# arr2 =
#  [[  9   3   1 101]
#  [  7   7   8 202]
#  [  1   5   5 303]
#  [  4   1   8 404]]

# %%
arr2 = np.append(arr1, [[101,1], [202,2], [303,3], [404,4]], axis=1)
print("After append:")
print("arr1 = \n", arr1)
print("arr2 = \n", arr2)
# Out:
# After append:
# arr1 =
#  [[9 3 1]
#  [7 7 8]
#  [1 5 5]
#  [4 1 8]]
# arr2 =
#  [[  9   3   1 101   1]
#  [  7   7   8 202   2]
#  [  1   5   5 303   3]
#  [  4   1   8 404   4]]

# %%
arr2 = np.append(arr1, [101,102,103,104], axis=1)
print("After append:")
print("arr1 = \n", arr1)
print("arr2 = \n", arr2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23036/2458049913.py in <module>
# ----> 1 arr2 = np.append(arr1, [101,102,103,104], axis=1)
#       2 print("After append:")
#       3 print("arr1 = \n", arr1)
#       4 print("arr2 = \n", arr2)
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in append(arr, values, axis)
#    4743         values = ravel(values)
#    4744         axis = arr.ndim-1
# -> 4745     return concatenate((arr, values), axis=axis)
#    4746
#    4747
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %% [markdown]
# ## 3. Inserting New Elements in Numpy Arrays
# - The `np.insert()` method allows us to insert new values along the given axis before the given index.
# - The method always returns a copy of the existing numpy array with the values inserted to the given axis.
# ```
# np.insert(arr, index, values, axis=None)
# ```
# - Where,
#     - `arr` is the array in which we want to insert
#     - `index` is the index before which we want to insert
#     - `values` [array_like] values to be added in the `arr`
#     - If `axis` is not specified, both `arr` and `values` are flattened before use.
#     - If `axis` is zero, a row is inserted (For 2-D arrays)
#     - If `axis` is one, a column is inserted (For 2-D arrays)
# - The original array remains as such, as it does not occur in-place.

# %% [markdown]
# ### a. Inserting Elements in 1-D Arrays

# %%
arr1 = np.random.randint(low = 1, high = 100, size = 5)
print("arr1 = ", arr1)
# Out:
# arr1 =  [45  5 35 11 61]

# %%
# You can insert a scalar value or a list of values in between array elements before the mentioned index
arr2 = np.insert(arr1, 3, 78)
print("After insert:")
print("arr1 = ", arr1)
print("arr2 = ", arr2)
# Out:
# After insert:
# arr1 =  [45  5 35 11 61]
# arr2 =  [45  5 35 78 11 61]

# %%
# You can insert a scalar value or a list of values in between array elements before the mentioned index
arr2 = np.insert(arr1, 3, 'hello')
print("After insert:")
print("arr1 = ", arr1)
print("arr2 = ", arr2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23036/3126862552.py in <module>
#       1 # You can insert a scalar value or a list of values in between array elements before the mentioned index
# ----> 2 arr2 = np.insert(arr1, 3, 'hello')
#       3 print("After insert:")
#       4 print("arr1 = ", arr1)
#       5 print("arr2 = ", arr2)
#
# <__array_function__ internals> in insert(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in insert(arr, obj, values, axis)
#    4638         # There are some object array corner cases here, but we cannot avoid
#    4639         # that:
# -> 4640         values = array(values, copy=False, ndmin=arr.ndim, dtype=arr.dtype)
#    4641         if indices.ndim == 0:
#    4642             # broadcasting is very different here, since a[:,0,:] = ... behaves
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
# You can insert a scalar value or a list of values in between array elements before the mentioned index
arr2 = np.insert(arr1, 3, [55, 66,77])
print("After insert:")
print("arr1 = ", arr1)
print("arr2 = ", arr2)
# Out:
# After insert:
# arr1 =  [45  5 35 11 61]
# arr2 =  [45  5 35 55 66 77 11 61]

# %% [markdown]
# ### b. Inserting Elements in 2-D Arrays

# %% [markdown]
# **Example:** In case of 2-D array, if `axis` is not mentioned the array is flattened first

# %%
arr1 = np.random.randint(low = 1, high = 10, size = (3,4))
print("arr1 = \n", arr1)
# Out:
# arr1 =
#  [[1 7 6 5]
#  [2 9 7 3]
#  [8 7 2 8]]

# %%
# Inserting a single value
arr2 = np.insert(arr1, 4, 55)
print("After insert:")
print("arr1 = \n", arr1)
print("arr2 = ", arr2)
# Out:
# After insert:
# arr1 =
#  [[1 7 6 5]
#  [2 9 7 3]
#  [8 7 2 8]]
# arr2 =  [ 1  7  6  5 55  2  9  7  3  8  7  2  8]

# %%
# Inserting a multiple values
arr2 = np.insert(arr1, 4, [55, 66])
print("After insert:")
print("arr1 = \n", arr1)
print("arr2 = ", arr2)
# Out:
# After insert:
# arr1 =
#  [[1 7 6 5]
#  [2 9 7 3]
#  [8 7 2 8]]
# arr2 =  [ 1  7  6  5 55 66  2  9  7  3  8  7  2  8]

# %% [markdown]
# **Example:** If axis=0, value(s) are added as a row before mentioned index

# %%
arr1 = np.random.randint(low = 1, high = 10, size = (3,4))
print("arr1 = \n", arr1)
# Out:
# arr1 =
#  [[1 1 1 4]
#  [7 2 3 5]
#  [9 6 3 8]]

# %%
# For axis = 0, note how the scalar value is replicated before insertion
arr2 = np.insert(arr1, 2, 55, axis=0)
print("After insert:")
print("arr1 = \n", arr1)
print("arr2 = \n", arr2)
# Out:
# After insert:
# arr1 =
#  [[1 1 1 4]
#  [7 2 3 5]
#  [9 6 3 8]]
# arr2 =
#  [[ 1  1  1  4]
#  [ 7  2  3  5]
#  [55 55 55 55]
#  [ 9  6  3  8]]

# %%
# For axis=0, note the size of values has to be 4 in this case (equal to number of columns)
arr2 = np.insert(arr1, 2, [55, 66,35,34], axis=0)
print("After insert:")
print("arr1 = \n", arr1)
print("arr2 = \n", arr2)
# Out:
# After insert:
# arr1 =
#  [[1 1 1 4]
#  [7 2 3 5]
#  [9 6 3 8]]
# arr2 =
#  [[ 1  1  1  4]
#  [ 7  2  3  5]
#  [55 66 35 34]
#  [ 9  6  3  8]]

# %% [markdown]
# **Example:** If axis=1, value(s) are added as a column at mentioned index

# %%
arr1 = np.random.randint(low = 1, high = 10, size = (3,4))
print("arr1 = \n", arr1)
# Out:
# arr1 =
#  [[8 5 1 8]
#  [4 2 3 7]
#  [9 5 4 3]]

# %%
# For axis = 1, note how the scalar value is replicated before insertion
arr2 = np.insert(arr1, 2, 55, axis=1)
print("After insert:")
print("arr1 = \n", arr1)
print("arr2 = \n", arr2)
# Out:
# After insert:
# arr1 =
#  [[8 5 1 8]
#  [4 2 3 7]
#  [9 5 4 3]]
# arr2 =
#  [[ 8  5 55  1  8]
#  [ 4  2 55  3  7]
#  [ 9  5 55  4  3]]

# %%
# For axis=1, note the size of values has to be 3 in this case (equal to number of rows)
arr2 = np.insert(arr1, 2, [55, 66, 77], axis=1)
print("After insert:")
print("arr1 = \n", arr1)
print("arr2 = \n", arr2)
# Out:
# After insert:
# arr1 =
#  [[8 5 1 8]
#  [4 2 3 7]
#  [9 5 4 3]]
# arr2 =
#  [[ 8  5 55  1  8]
#  [ 4  2 66  3  7]
#  [ 9  5 77  4  3]]

# %% [markdown]
# ## 4. Deleting  Elements of Numpy Arrays
# - The `np.delete()` method allows us to delete value(s) from an array at the given index
# - This function always returns a copy of the existing numpy array with the values deleted from the given axis.
# - If axis is not specified, values can be of any shape and will be flattened before use
# ```
# np.delete(arr, index, axis=None)
# ```
# - The original array remains as such, as it does not occur in-place.

# %% [markdown]
# ### a. Deleting Elements from a 1-D Arrays

# %% [markdown]
# **Example:**

# %%
arr1 = np.random.randint(low = 1, high = 10, size = 5)
print("arr1 = ", arr1)
# Out:
# arr1 =  [2 4 6 1 5]

# %%
# You can delete a scalar value from a specific index
arr2 = np.delete(arr1, 3)
print("After delete:")
print("arr1 = ", arr1)
print("arr2 = ", arr2)
# Out:
# After delete:
# arr1 =  [2 4 6 1 5]
# arr2 =  [2 4 6 5]

# %%
arr3 = np.delete(arr1,[0,1,2,3])
arr3
# Out:
# array([5])

# %%
arr1
# Out:
# array([2, 4, 6, 1, 5])

# %% [markdown]
# **Example:**

# %%
arr1 = np.random.randint(low = 1, high = 100, size = 10)
print("arr1 = ", arr1)
# Out:
# arr1 =  [37 20 31 50 49 19 57 64 81 26]

# %%
# You can delete a list of values in between array elements from specific indices
arr2 = np.delete(arr1, [2,5])
print("After delete:")
print("arr1 = ", arr1)
print("arr2 = ", arr2)
# Out:
# After delete:
# arr1 =  [37 20 31 50 49 19 57 64 81 26]
# arr2 =  [37 20 50 49 57 64 81 26]

# %% [markdown]
# ### b. Deleting Elements from a 2-D Arrays

# %% [markdown]
# **Example:** Delete a specific element from a 2-D array, don't mention the axis. The resulting array is flattened before use

# %%
arr1 = np.random.randint(low = 1, high = 10, size = (3,3))
print("arr1 = \n", arr1)
# Out:
# arr1 =
#  [[8 8 6]
#  [8 5 9]
#  [2 3 4]]

# %%
arr2 = np.delete(arr1, 5)
print("After delete:")
print("arr1 = \n", arr1)
print("arr2 = ", arr2)
# Out:
# After delete:
# arr1 =
#  [[8 8 6]
#  [8 5 9]
#  [2 3 4]]
# arr2 =  [8 8 6 8 5 2 3 4]

# %%
arr2.shape
# Out:
# (8,)

# %%
arr1.shape
# Out:
# (3, 3)

# %%
arr2.size
# Out:
# 8

# %%
arr1.size
# Out:
# 9

# %% [markdown]
# **Example:**  Delete a specific row from an existing 2-D array

# %%
arr1 = np.random.randint(low = 1, high = 10, size = (4,4))
print("arr1 = \n", arr1)
# Out:
# arr1 =
#  [[8 8 1 7]
#  [9 4 5 5]
#  [6 9 2 9]
#  [4 4 7 1]]

# %%
arr2 = np.delete(arr1, 2, axis=0)
print("After delete:")
print("arr1 = \n", arr1)
print("arr2 = \n", arr2)
# Out:
# After delete:
# arr1 =
#  [[8 8 1 7]
#  [9 4 5 5]
#  [6 9 2 9]
#  [4 4 7 1]]
# arr2 =
#  [[8 8 1 7]
#  [9 4 5 5]
#  [4 4 7 1]]

# %%
arr3 = np.delete(arr1,[2][0],axis = 0)

# %%
arr1
# Out:
# array([[5, 1, 7, 2],
#        [8, 3, 4, 7],
#        [3, 3, 7, 4],
#        [5, 2, 5, 2]])

# %%
arr3
# Out:
# array([[5, 1, 7, 2],
#        [8, 3, 4, 7],
#        [5, 2, 5, 2]])

# %%
arr3 = np.delete(arr1,[0][0],axis = 0)

# %%
arr3
# Out:
# array([[8, 3, 4, 7],
#        [3, 3, 7, 4],
#        [5, 2, 5, 2]])

# %% [markdown]
# **Example:**  Delete a specific column from an existing 2-D array

# %%
arr1 = np.random.randint(low = 1, high = 10, size = (4,4))
print("arr1 = \n", arr1)
# Out:
# arr1 =
#  [[7 6 7 7]
#  [5 7 7 2]
#  [5 8 4 2]
#  [3 9 6 6]]

# %%
arr2 = np.delete(arr1, 2, axis=1)
print("After delete:")
print("arr1 = \n", arr1)
print("arr2 = \n", arr2)
# Out:
# After delete:
# arr1 =
#  [[7 6 7 7]
#  [5 7 7 2]
#  [5 8 4 2]
#  [3 9 6 6]]
# arr2 =
#  [[7 6 7]
#  [5 7 2]
#  [5 8 2]
#  [3 9 6]]

# %% [markdown]
# ## 5. Assigning vs Coping NumPy Arrays

# %% [markdown]
# ### a. Assigning two NumPy Arrays (Create an alias)

# %%
arr1 = np.random.randint(low = 1, high = 10, size = 10)

# Creating a copy using assignment operator, both variables point at the same array
arr2 = arr1

print("arr1 = ", arr1)
print("arr2 = ", arr2)
print(id(arr1))
print(id(arr2))
# Out:
# arr1 =  [8 3 1 6 2 1 9 6 4 7]
# arr2 =  [8 3 1 6 2 1 9 6 4 7]
# 2187831436944
# 2187831436944

# %%
# Change value in arr1 will also occur in arr2
arr2[2] = 55
print("arr1 = ", arr1)
print("arr2 = ", arr2)
# Out:
# arr1 =  [ 8  3 55  6  2  1  9  6  4  7]
# arr2 =  [ 8  3 55  6  2  1  9  6  4  7]

# %% [markdown]
# ### b. View/Shallow Copy
# Arrays that share some data. The view method creates an object looking at the same data. Slicing an array returns a view of that array.

# %%
import numpy as np
arr1 = np.random.randint(low = 1, high = 10, size = 10)

# Creating a shallow copy (view) using slice operator
arr2 = arr1[:]

print("arr1 = ", arr1)
print("arr2 = ", arr2)
print(id(arr1))
print(id(arr2))
# Out:
# arr1 =  [9 6 2 9 9 6 7 8 1 5]
# arr2 =  [9 6 2 9 9 6 7 8 1 5]
# 2187831438960
# 2187814020656

# %%
# Change value in arr1 will occur in arr2
arr2[2] = 55

print("arr1 = ", arr1)
print("arr2 = ", arr2)
# Out:
# arr1 =  [ 9  6 55  9  9  6  7  8  1  5]
# arr2 =  [ 9  6 55  9  9  6  7  8  1  5]

# %% [markdown]
# ### c. Deep Copy

# %%
arr1 = np.random.randint(low = 1, high = 10, size = 10)

# Create a Deep copy using copy() method, which will create a new copy of the array
arr2 = arr1.copy()
print("arr1 = ", arr1)
print("arr2 = ", arr2)
print(id(arr1))
print(id(arr2))
# Out:
# arr1 =  [2 7 4 5 1 7 8 4 5 1]
# arr2 =  [2 7 4 5 1 7 8 4 5 1]
# 2187830624304
# 2187831439248

# %%
# Change value in array 1 will NOT occur in array 2
arr2[2] = 55

print("arr1 = ", arr1)
print("arr2 = ", arr2)
# Out:
# arr1 =  [2 7 4 5 1 7 8 4 5 1]
# arr2 =  [ 2  7 55  5  1  7  8  4  5  1]
